# %% [markdown]
# * How to track add source file name in one of column in dataframe?
# * Answer: Using input_file_name() function and withColumn() function we can add new column for filenames.

# %%
df_airlines = spark.read.csv("/databricks-datasets/asa/airlines",header=True)

# %%
from pyspark.sql.functions import input_file_name
df_airlines = df_airlines.withColumn("FILE_NAME",input_file_name())

# %% [markdown]
# * Get no of rows on each file in a dataframe?
# * Answer: Using input_file_name() function and groupBy transaformation we can achive no of row on each file

# %%
display(df_airlines.groupBy("FILE_NAME").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>FILE_NAME</th><th>count</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/asa/airlines/2007.csv</td><td>7453215</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2008.csv</td><td>7009728</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2006.csv</td><td>7141922</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2005.csv</td><td>7140596</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2004.csv</td><td>7129270</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2003.csv</td><td>6488540</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2001.csv</td><td>5967780</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2000.csv</td><td>5683047</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1999.csv</td><td>5527884</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1997.csv</td><td>5411843</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1998.csv</td><td>5384721</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1996.csv</td><td>5351983</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1995.csv</td><td>5327435</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/2002.csv</td><td>5271359</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1990.csv</td><td>5270893</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1994.csv</td><td>5180048</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1988.csv</td><td>5202096</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1992.csv</td><td>5092157</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1991.csv</td><td>5076925</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1993.csv</td><td>5070501</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1989.csv</td><td>5041200</td></tr><tr><td>dbfs:/databricks-datasets/asa/airlines/1987.csv</td><td>1311826</td></tr></tbody></table></div>
