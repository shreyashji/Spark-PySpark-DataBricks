# %% [markdown]
# * How to add partitionId in dataframe
# * Answer: Using spark_partition_id function and withColumn we can get partitionid and add into dataframe

# %%
# %fs ls /databricks-datasets/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_airlines = spark.read.csv("/databricks-datasets/asa/airlines",header=True)

# %%
from pyspark.sql.functions import spark_partition_id
df_airlines = df_airlines.withColumn("PART_ID",spark_partition_id())

# %% [markdown]
# * How to get row count by partitionId in dataframe
# * Answer: Using spark_partition_id function and withColumn we can get partitionid and add into dataframe

# %%
display(df_airlines.groupBy("PART_ID").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
